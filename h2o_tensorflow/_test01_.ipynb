# %%
import scipy as sp

# %%
import patsy

# %%
import future

# %%
import statsmodels

# %%
import pandas as pd

# %%
import numpy as np

# %%
import h2o

# %%
h2o.__version__
# Out:
# '3.6.0.8'

# %%
import h2o
import os
import tabulate
import operator 
from h2o.estimators.glm import H2OGeneralizedLinearEstimator
from h2o.estimators.deeplearning import H2ODeepLearningEstimator

# %%
h2o.init()
# Out:
# --------------------------  -------------------------------------
# H2O cluster uptime:         48 minutes 9 seconds 616 milliseconds
# H2O cluster version:        3.6.0.8
# H2O cluster name:           H2O_started_from_python
# H2O cluster total nodes:    1
# H2O cluster total memory:   643.81 MB
# H2O cluster total cores:    1
# H2O cluster allowed cores:  1
# H2O cluster healthy:        True
# H2O Connection ip:          127.0.0.1
# H2O Connection port:        54321
# --------------------------  -------------------------------------

# %%
airlines_hex = h2o.import_file(path = os.path.realpath("allyears2k.csv"),
                               destination_frame = "airlines.hex")
airlines_hex.describe()
# Out:
# Parse Progress: [##################################################] 100%
# Rows:43,978 Cols:31
#
# Chunk compression summary:
# chunk_type    chunk_name                 count    count_percentage    size      size_percentage
# ------------  -------------------------  -------  ------------------  --------  -----------------
# C0L           Constant Integers          7        5.64516             560  B    0.0353897
# C0D           Constant Reals             18       14.5161             1.4 KB    0.0910021
# CBS           Bits                       2        1.6129              2.6 KB    0.165826
# CX0           Sparse Bits                6        4.83871             1.5 KB    0.0946675
# C1            1-Byte Integers            27       21.7742             304.3 KB  19.692
# C1N           1-Byte Integers (w/o NAs)  11       8.87097             115.7 KB  7.48713
# C1S           1-Byte Fractions           4        3.22581             43.3 KB   2.80046
# C2            2-Byte Integers            49       39.5161             1.1 MB    69.6335
# Frame distribution summary:
#                  size    number_of_rows    number_of_chunks_per_column    number_of_chunks
# ---------------  ------  ----------------  -----------------------------  ------------------
# 127.0.0.1:54321  1.5 MB  43978             4                              124
# mean             1.5 MB  43978             4                              124
# min              1.5 MB  43978             4                              124
# max              1.5 MB  43978             4                              124
# stddev           0  B    0                 0                              0
# total            1.5 MB  43978             4                              124
# <table>
# <tr><th>       </th><th>Year         </th><th>Month        </th><th>DayofMonth   </th><th>DayOfWeek    </th><th>DepTime      </th><th>CRSDepTime   </th><th>ArrTime      </th><th>CRSArrTime   </th><th>UniqueCarrier  </th><th>FlightNum    </th><th>TailNum  </th><th>ActualElapsedTime  </th><th>CRSElapsedTime  </th><th>AirTime      </th><th>ArrDelay     </th><th>DepDelay     </th><th>Origin  </th><th>Dest  </th><th>Distance     </th><th>TaxiIn       </th><th>TaxiOut      </th><th>Cancelled      </th><th>CancellationCode  </th><th>Diverted        </th><th>CarrierDelay  </th><th>WeatherDelay  </th><th>NASDelay     </th><th>SecurityDelay  </th><th>LateAircraftDelay  </th><th>IsArrDelayed  </th><th>IsDepDelayed  </th></tr>
# <tr><td>type   </td><td>int          </td><td>int          </td><td>int          </td><td>int          </td><td>int          </td><td>int          </td><td>int          </td><td>int          </td><td>enum           </td><td>int          </td><td>enum     </td><td>int                </td><td>int             </td><td>int          </td><td>int          </td><td>int          </td><td>enum    </td><td>enum  </td><td>int          </td><td>int          </td><td>int          </td><td>int            </td><td>enum              </td><td>int             </td><td>int           </td><td>int           </td><td>int          </td><td>int            </td><td>int                </td><td>enum          </td><td>enum          </td></tr>
# <tr><td>mins   </td><td>1987.0       </td><td>1.0          </td><td>1.0          </td><td>1.0          </td><td>1.0          </td><td>0.0          </td><td>1.0          </td><td>0.0          </td><td>0.0            </td><td>1.0          </td><td>0.0      </td><td>16.0               </td><td>17.0            </td><td>14.0         </td><td>-63.0        </td><td>-16.0        </td><td>0.0     </td><td>0.0   </td><td>11.0         </td><td>0.0          </td><td>0.0          </td><td>0.0            </td><td>0.0               </td><td>0.0             </td><td>0.0           </td><td>0.0           </td><td>0.0          </td><td>0.0            </td><td>0.0                </td><td>0.0           </td><td>0.0           </td></tr>
# <tr><td>mean   </td><td>1997.5       </td><td>1.40909090909</td><td>14.6010732639</td><td>3.82061485288</td><td>1345.84666138</td><td>1313.22286143</td><td>1504.63413038</td><td>1485.28916731</td><td>NaN            </td><td>818.842989677</td><td>NaN      </td><td>124.814529135      </td><td>125.021562607   </td><td>114.316111091</td><td>9.31711193698</td><td>10.0073906556</td><td>NaN     </td><td>NaN   </td><td>730.182190565</td><td>5.38136805953</td><td>14.1686341847</td><td>0.0246941652645</td><td>NaN               </td><td>0.00247851198326</td><td>4.04780029106 </td><td>0.289376469271</td><td>4.85503190418</td><td>0.0170155602821</td><td>7.62006045002      </td><td>0.555755150302</td><td>0.525057983537</td></tr>
# <tr><td>maxs   </td><td>2008.0       </td><td>10.0         </td><td>31.0         </td><td>7.0          </td><td>2400.0       </td><td>2359.0       </td><td>2400.0       </td><td>2359.0       </td><td>9.0            </td><td>3949.0       </td><td>3500.0   </td><td>475.0              </td><td>437.0           </td><td>402.0        </td><td>475.0        </td><td>473.0        </td><td>131.0   </td><td>133.0 </td><td>3365.0       </td><td>128.0        </td><td>254.0        </td><td>1.0            </td><td>3.0               </td><td>1.0             </td><td>369.0         </td><td>201.0         </td><td>323.0        </td><td>14.0           </td><td>373.0              </td><td>1.0           </td><td>1.0           </td></tr>
# <tr><td>sigma  </td><td>6.34436090171</td><td>1.87471137134</td><td>9.17579042586</td><td>1.90501311913</td><td>465.340899124</td><td>476.251139993</td><td>484.347487904</td><td>492.750434123</td><td>NaN            </td><td>777.404369164</td><td>NaN      </td><td>73.9744416606      </td><td>73.40159463     </td><td>69.6363295151</td><td>29.8402219624</td><td>26.4388090429</td><td>NaN     </td><td>NaN   </td><td>578.43800823 </td><td>4.20197993986</td><td>9.9050857472 </td><td>0.155193141358 </td><td>NaN               </td><td>0.0497234872189 </td><td>16.2057299045 </td><td>4.41677989873 </td><td>18.6197762215</td><td>0.403940182102 </td><td>23.4875658741      </td><td>0.496887288343</td><td>0.499377380318</td></tr>
# <tr><td>zeros  </td><td>0            </td><td>0            </td><td>0            </td><td>0            </td><td>0            </td><td>569          </td><td>0            </td><td>569          </td><td>724            </td><td>0            </td><td>2        </td><td>0                  </td><td>0               </td><td>-10159       </td><td>1514         </td><td>6393         </td><td>59      </td><td>172   </td><td>0            </td><td>-9536        </td><td>-9602        </td><td>42892          </td><td>81                </td><td>43869           </td><td>-22684        </td><td>-21188        </td><td>-22640       </td><td>-21114         </td><td>-22888             </td><td>19537         </td><td>20887         </td></tr>
# <tr><td>missing</td><td>0            </td><td>0            </td><td>0            </td><td>0            </td><td>1086         </td><td>0            </td><td>1195         </td><td>0            </td><td>0              </td><td>0            </td><td>32       </td><td>1195               </td><td>13              </td><td>16649        </td><td>1195         </td><td>1086         </td><td>0       </td><td>0     </td><td>35           </td><td>16026        </td><td>16024        </td><td>0              </td><td>9774              </td><td>0               </td><td>35045         </td><td>35045         </td><td>35045        </td><td>35045          </td><td>35045              </td><td>0             </td><td>0             </td></tr>
# <tr><td>0      </td><td>1987.0       </td><td>10.0         </td><td>14.0         </td><td>3.0          </td><td>741.0        </td><td>730.0        </td><td>912.0        </td><td>849.0        </td><td>PS             </td><td>1451.0       </td><td>NA       </td><td>91.0               </td><td>79.0            </td><td>nan          </td><td>23.0         </td><td>11.0         </td><td>SAN     </td><td>SFO   </td><td>447.0        </td><td>nan          </td><td>nan          </td><td>0.0            </td><td>NA                </td><td>0.0             </td><td>nan           </td><td>nan           </td><td>nan          </td><td>nan            </td><td>nan                </td><td>YES           </td><td>YES           </td></tr>
# <tr><td>1      </td><td>1987.0       </td><td>10.0         </td><td>15.0         </td><td>4.0          </td><td>729.0        </td><td>730.0        </td><td>903.0        </td><td>849.0        </td><td>PS             </td><td>1451.0       </td><td>NA       </td><td>94.0               </td><td>79.0            </td><td>nan          </td><td>14.0         </td><td>-1.0         </td><td>SAN     </td><td>SFO   </td><td>447.0        </td><td>nan          </td><td>nan          </td><td>0.0            </td><td>NA                </td><td>0.0             </td><td>nan           </td><td>nan           </td><td>nan          </td><td>nan            </td><td>nan                </td><td>YES           </td><td>NO            </td></tr>
# <tr><td>2      </td><td>1987.0       </td><td>10.0         </td><td>17.0         </td><td>6.0          </td><td>741.0        </td><td>730.0        </td><td>918.0        </td><td>849.0        </td><td>PS             </td><td>1451.0       </td><td>NA       </td><td>97.0               </td><td>79.0            </td><td>nan          </td><td>29.0         </td><td>11.0         </td><td>SAN     </td><td>SFO   </td><td>447.0        </td><td>nan          </td><td>nan          </td><td>0.0            </td><td>NA                </td><td>0.0             </td><td>nan           </td><td>nan           </td><td>nan          </td><td>nan            </td><td>nan                </td><td>YES           </td><td>YES           </td></tr>
# <tr><td>3      </

# %%
# Set predictor and response variables
myY = "IsDepDelayed"
myX = ["Dest", "Origin", "DayofMonth", "Year", "UniqueCarrier", "DayOfWeek", "Month", "Distance"]

# GLM - Predict Delays
glm_model = H2OGeneralizedLinearEstimator(
    family = "binomial",standardize = True, solver = "IRLSM",
    link = "logit", alpha = 0.5, model_id = "glm_model_from_python" )
glm_model.train(x               = myX,
               y               = myY,
               training_frame  = airlines_hex)
# Out:
# glm Model Build Progress: [##################################################] 100%

# %%
print "AUC of the training set : " + str(glm_model.auc())
# Variable importances from each algorithm
# Calculate magnitude of normalized GLM coefficients
glm_varimp = glm_model.coef_norm()
for k,v in glm_varimp.iteritems():
    glm_varimp[k] = abs(glm_varimp[k])
    
# Sort in descending order by magnitude
glm_sorted = sorted(glm_varimp.items(), key = operator.itemgetter(1), reverse = True)
table = tabulate.tabulate(glm_sorted, headers = ["Predictor", "Normalized Coefficient"], tablefmt = "orgtbl")
print "Variable Importances:\n\n" + table
# Out:
# AUC of the training set : 0.702879698848
# Variable Importances:
#
# | Predictor        |   Normalized Coefficient |
# |------------------+--------------------------|
# | Origin.MDW       |              1.72856     |
# | Origin.AUS       |              1.30966     |
# | Origin.HNL       |              1.03096     |
# | UniqueCarrier.WN |              0.985918    |
# | Origin.ERI       |              0.972954    |
# | Origin.TLH       |              0.914883    |
# | Origin.ATL       |              0.905639    |
# | Origin.LIH       |              0.877535    |
# | Origin.MYR       |              0.86482     |
# | Origin.BUR       |              0.863066    |
# | Origin.PSP       |              0.846814    |
# | UniqueCarrier.TW |              0.809874    |
# | Dest.LYH         |              0.768895    |
# | Origin.HPN       |              0.754289    |
# | Origin.BNA       |              0.753831    |
# | Origin.ABQ       |              0.738563    |
# | Origin.PBI       |              0.721386    |
# | Origin.STL       |              0.712129    |
# | Origin.IAH       |              0.709305    |
# | Origin.ORD       |              0.678965    |
# | Origin.MIA       |              0.662226    |
# | Origin.OGG       |              0.654954    |
# | Dest.FLL         |              0.631184    |
# | Origin.BOI       |              0.603456    |
# | Origin.GSO       |              0.595228    |
# | UniqueCarrier.HP |              0.583614    |
# | Dest.DAY         |              0.57794     |
# | Origin.ACY       |              0.575542    |
# | Origin.BHM       |              0.569211    |
# | Dest.TPA         |              0.556467    |
# | Origin.MCO       |              0.549832    |
# | Origin.SYR       |              0.536645    |
# | Origin.SRQ       |              0.526342    |
# | UniqueCarrier.PS |              0.524627    |
# | Origin.RNO       |              0.50216     |
# | Dest.SFO         |              0.500227    |
# | Dest.CAE         |              0.498676    |
# | Dest.COS         |              0.496017    |
# | Dest.BTV         |              0.492907    |
# | Origin.PIT       |              0.490955    |
# | Dest.SLC         |              0.484347    |
# | Origin.LAX       |              0.483646    |
# | Dest.ICT         |              0.479551    |
# | Dest.IAH         |              0.477908    |
# | Origin.CMH       |              0.470863    |
# | Origin.SLC       |              0.468736    |
# | Origin.LEX       |              0.468493    |
# | Dest.SMF         |              0.466155    |
# | Origin.OMA       |              0.459968    |
# | Origin.PWM       |              0.457474    |
# | Dest.CLE         |              0.452222    |
# | Origin.AVP       |              0.451931    |
# | Origin.LGA       |              0.448433    |
# | Origin.CRW       |              0.446781    |
# | Dest.ABQ         |              0.43417     |
# | Dest.PBI         |              0.433494    |
# | Origin.EGE       |              0.423435    |
# | Dest.MCO         |              0.420506    |
# | Origin.CHO       |              0.415939    |
# | Origin.STX       |              0.413432    |
# | Dest.IAD         |              0.411808    |
# | Origin.IAD       |              0.405919    |
# | Origin.SAV       |              0.403895    |
# | Dest.CLT         |              0.403762    |
# | Origin.DFW       |              0.400587    |
# | Origin.JAX       |              0.395605    |
# | Origin.IND       |              0.393343    |
# | Dest.IND         |              0.390445    |
# | Dest.CHO         |              0.389568    |
# | Origin.LYH       |              0.389568    |
# | Origin.DEN       |              0.376833    |
# | Year             |              0.368682    |
# | Dest.ISP         |              0.365388    |
# | Origin.ROC       |              0.364895    |
# | Origin.BDL       |              0.364252    |
# | Dest.PNS         |              0.359932    |
# | Dest.OMA         |              0.35629     |
# | UniqueCarrier.DL |              0.350352    |
# | Dest.HTS         |              0.350017    |
# | Origin.BTV       |              0.347367    |
# | Dest.CMH         |              0.343893    |
# | Origin.JFK       |              0.342777    |
# | Origin.DAY       |              0.340336    |
# | Dest.STL         |              0.336629    |
# | Origin.SAT       |              0.334018    |
# | Dest.SBN         |              0.329853    |
# | Dest.BUF         |              0.32818     |
# | Origin.CLE       |              0.327252    |
# | Origin.ROA       |              0.327049    |
# | Dest.DFW         |              0.325665    |
# | Origin.SWF       |              0.32192     |
# | Dest.GSO         |              0.320784    |
# | UniqueCarrier.UA |              0.314472    |
# | Dest.MIA         |              0.31419     |
# | Origin.LBB       |              0.31371     |
# | Origin.MRY       |              0.304565    |
# | Dest.MDW         |              0.300265    |
# | Dest.MKE         |              0.290248    |
# | Origin.MKE       |              0.288186    |
# | Origin.PHL       |              0.287696    |
# | Dest.FAT         |              0.28725     |
# | Dest.MDT         |              0.285925    |
# | DayofMonth       |              0.279556    |
# | Origin.PDX       |              0.278739    |
# | Dest.FAY         |              0.273211    |
# | Origin.MCI       |              0.269141    |
# | Origin.TUS       |              0.26061     |
# | Dest.BWI         |              0.25475     |
# | Origin.BOS       |              0.243748    |
# | Dest.PSP         |              0.240178    |
# | Origin.ALB       |              0.239953    |
# | Dest.BUR         |              0.238351    |
# | Origin.FLL       |              0.237068    |
# | Origin.ONT       |              0.230946    |
# | Origin.TPA       |              0.230279    |
# | Dest.PHL         |              0.228939    |
# | Origin.PVD       |              0.225794    |
# | Origin.SFO       |              0.22493     |
# | Dest.EWR         |              0.221988    |
# | Dest.HNL         |              0.221502    |
# | Origin.MSY       |              0.218836    |
# | Dest.BDL         |              0.218257    |
# | Dest.BGM         |              0.216254    |
# | Dest.PHF         |              0.216194    |
# | Dest.SAT         |              0.21173     |
# | Dest.DEN         |              0.209852    |
# | Dest.CHS         |              0.200478    |
# | Origin.SAN       |              0.200293    |
# | Dest.RDU         |              0.191828    |
# | Dest.AVP         |              0.188497    |
# | Origin.DSM       |              0.18609     |
# | Dest.ONT         |              0.183718    |
# | Dest.GEG         |              0.180365    |
# | Origin.TUL       |              0.167334    |
# | Origin.OAK       |              0.166777    |
# | Dest.MSY         |              0.164305    |
# | Dest.DAL         |              0.163248    |
# | Dest.HOU         |              0.157782    |
# | Dest.UCA         |              0.157012    |
# | Dest.ATL         |              0.151616    |
# | Dest.SEA         |              0.151392    |
# | Origin.CRP       |              0.151211    |
# | Origin.LAS       |              0.145685    |
# | Origin.CLT       |              0.131177    |
# | Distance         |              0.130035    |
# | Dest.SNA         |              0.128734    |
# | Dest.SJC         |              0.127647    |
# | Dest.ROA         |              0.127313    |
# | Dest.RSW         |              0.123473    |
# | Dest.MSP         |              0.119571    |
# | Origin.OKC       |              0.119141    |
# | Origin.RSW       |              0.116606    |
# | Dest.AVL         |              0.114281    |
# | Dest.LAX         |              0.111135    |
# | Origin.MSP       |              0.108256    |
# | Dest.DTW         |              0.104584    |
# | Dest.JAX         |              0.10242     |
# | Dest.LAS         |              0.101775    |
# | Dest.ORF         |              0.101166    |
# | Month            |              0.100357    |
# | Dest.OGG         |              0.0965604   |
# | Dest.SAN         |              0.0960577   |
# | Origin.DCA       |              0.0953053   |
# | Origin.ORF       |              0.0912398   |
# | Origin.RIC       |              0.0903304   |
# | Dest.LGA         |              0.0830924   |
# | Origin.CVG       |              0.077105    |
# | Dest.BHM         |              0.0698923   |
# | Dest.PHX         |              0.065596    |
# | Origin.MEM       |              0.0632878   |
# | Origin.SEA       |              0.0627142   |
# | Origin.GEG       |              0.0615856   |
# | Origin.HOU       |              0.0582941   |
# | Origin.SDF       |              0.0559588   |
# | Origin.EWR       |              0.0539727   |
# | Dest.OAK         |              0.05379     |
# | Dest.PDX         |              0.0486173   |
# | Origin.DTW       |              0.0482347   |
# | Dest.LBB         |              0.0475272   |
# | Origin.SJC       |              0.0458656   |
# | Dest.CAK         |              0.0443232   |
# | Origin.DAL       |              0.0440432   |
# | Dest.TUL         |              0.0432786   |
# | Dest.BNA         |              0.0426651   |
# | Dest.ORD         |              0.0414205   |
# | DayOfWeek        |              0.0409265   |
# | Origin.BWI       |              0.0399085   |
# | UniqueCarrier.US |              0.0365074   |
# | Origin.SJU       |              0.0352703   |
# | Origin.GRR       |              0.0333617   |
# | Origin.SNA       |              0.0329569   |
# | Dest.AUS         |              0.032008    |
# | Dest.ROC         |              0.0316031   |
# | Dest.DCA         |              0.029796    |
# | Intercept        |              0.02671     |
# | Dest.TUS         |              0.0235818   |
# | Dest.MHT         |              0.0206439   |
# | Origin.PHX       |              0.0182569   |
# | Origin.MAF       |              0.0135527   |
# | Dest.BOS         |              0.0116548   |
# | Origin.SMF       |              0.00899423  |
# | Dest.SWF         |              0.00785591  |
# | Dest.ELP         |              0.00722268  |
# | Dest.ABE         |              0.00718274  |
# | Dest.PIT         |              0.00300626  |
# | Dest.CVG         |              0.00263122  |
# | Dest.LIH         |              1.01742e-05 |
# | Dest.LIT         |              0           |
# | Dest.OKC         |              0           |
# | Origin.BGM       |              0           |
# | Dest.MCI         |              0           |
# | Dest.HPN         |              0           |
# | Dest.ORH         |              0           |
# | Dest.RNO         |              0           |
# | Origin.ANC       |              0           |
# | Dest.SRQ         |              0           |
# | Dest.MRY         |              0           |
# | Dest.SJU         |              0           |
# | Origin.TRI       |              0           |
# | Origin.CAE       |              0           |
# | Dest.DSM         |              0           |
# | Origin.RDU       |              0           |
# | Origin.SCK       |              0           |
# | Dest.PWM         |              0           |
# | Origin.ISP       |              0           |
# | Origin.LAN       |              0           |
# | Origin.ICT       |              0           |
# | Origin.LIT       |              0           |
# | Dest.GRR         |              0           |
# | Origin.KOA       |              0           |
# | Origin.UCA       |              0           |
# | Dest.JFK         |              0           |
# | Dest.PVD         |              0           |
# | Origin.AMA       |              0           |
# | Dest.ERI         |              0           |
# | Dest.ACY         |              0           |
# | Dest.FNT         |              0           |
# | Dest.GSP         |              0           |
# | Origin.MDT       |              0           |
# | Dest.OAJ         |              0           |
# | Dest.CRP         |              0           |
# | Origin.MFR       |              0           |
# | Origin.CHS       |              0           |
# | Dest.SYR         |              0           |
# | Origin.MHT       |              0           |
# | Dest.JAN         |              0           |
# | Dest.ALB         |              0           |
# | Origin.STT       |              0           |
# | Origin.EYW       |              0           |
# | Origin.COS       |              0           |
# | Dest.ELM         |              0           |
# | Dest.CHA         |              0           |
# | Origin.ABE       |              0           |
# | Origin.SBN       |              0           |
# | Origin.BUF       |              0           |
# | Origin.HRL       |              0           |
# | Origin.GNV       |              0           |
# | Dest.AMA         |              0           |
# | Dest.LEX         |              0           |
# | Dest.RIC         |              0           |
# | Origin.TYS       |              0           |
# | Origin.JAN       |              0           |
# | Dest.BOI         |              0           |
# | Origin.MLB       |              0           |
# | Dest.KOA         |              0           |
# | Dest.ILM         |              0           |
# | Dest.MAF         |              0           |
# | Dest.SDF         |              0           |
# | Dest.TOL         |              0           |
# | Dest.ANC         |              0           |
# | Dest.HRL         |              0           |
# | Dest.STT         |              0           |
# | Dest.EYW         |              0           |
# | UniqueCarrier.AA |              0           |
# | UniqueCarrier.CO |              0           |
# | Origin.ELP       |              0           |
# | UniqueCarrier.PI |              0           |
# | Dest.EUG         |              0           |
# | Dest.MYR         |              0           |
# | Dest.SCK         |              0           |
# | Origin.PHF       |              0           |
# | Origin.BIL       |              0           |

# %%
# Deep Learning - Predict Delays
deeplearning_model = H2ODeepLearningEstimator(
    distribution = "bernoulli", model_id = "deeplearning_model_from_python",
    epochs = 100, hidden = [200,200],  
    seed = 6765686131094811000, variable_importances = True)
deeplearning_model.train(x               = myX,
                         y               = myY,
                         training_frame  = airlines_hex)
# Out:
# deeplearning Model Build Progress: [##################################################] 100%

# %%
print "AUC of the training set : " + str(deeplearning_model.auc())
deeplearning_model.varimp(table)
# Out:
# AUC of the training set : 0.897286942712
#                       variable  relative_importance  scaled_importance  \
# 0             UniqueCarrier.PS             1.000000           1.000000
# 1                         Year             0.964307           0.964307
# 2                   DayofMonth             0.934966           0.934966
# 3                    DayOfWeek             0.917722           0.917722
# 4                     Dest.PHX             0.682071           0.682071
# 5                     Dest.PHL             0.673968           0.673968
# 6             UniqueCarrier.UA             0.656903           0.656903
# 7                     Dest.EWR             0.635984           0.635984
# 8             UniqueCarrier.US             0.633332           0.633332
# 9                     Dest.SFO             0.610181           0.610181
# 10                    Dest.PIT             0.558645           0.558645
# 11                  Origin.PIT             0.548508           0.548508
# 12                  Origin.SFO             0.541465           0.541465
# 13                    Dest.IAH             0.536600           0.536600
# 14                    Dest.LAX             0.528432           0.528432
# 15                  Origin.IND             0.520081           0.520081
# 16                  Origin.CLE             0.519257           0.519257
# 17                  Origin.CLT             0.519216           0.519216
# 18            UniqueCarrier.WN             0.513491           0.513491
# 19                    Dest.ORD             0.512417           0.512417
# 20                  Origin.ORD             0.512395           0.512395
# 21                  Origin.LAX             0.510593           0.510593
# 22                    Dest.BUR             0.509504           0.509504
# 23                    Distance             0.508083           0.508083
# 24                    Dest.BDL             0.504951           0.504951
# 25                  Origin.PHL             0.503935           0.503935
# 26                  Origin.RDU             0.502483           0.502483
# 27            UniqueCarrier.HP             0.496996           0.496996
# 28                    Dest.MCO             0.491314           0.491314
# 29                    Dest.LAS             0.490042           0.490042
# ..                         ...                  ...                ...
# 254                 Origin.AMA             0.196390           0.196390
# 255                   Dest.LEX             0.195878           0.195878
# 256                   Dest.STT             0.194709           0.194709
# 257                   Dest.UCA             0.194536           0.194536
# 258                 Origin.GRR             0.194271           0.194271
# 259                 Origin.KOA             0.193543           0.193543
# 260                   Dest.LIT             0.193095           0.193095
# 261                   Dest.CRP             0.191422           0.191422
# 262                   Dest.DSM             0.191242           0.191242
# 263                   Dest.CHA             0.191079           0.191079
# 264                   Dest.JAN             0.190444           0.190444
# 265                   Dest.ANC             0.190189           0.190189
# 266                   Dest.DAL             0.189525           0.189525
# 267                 Origin.STT             0.189409           0.189409
# 268                 Origin.GNV             0.188741           0.188741
# 269                   Dest.MRY             0.188515           0.188515
# 270                 Origin.HRL             0.187615           0.187615
# 271                   Dest.ORH             0.187452           0.187452
# 272                 Origin.ANC             0.185476           0.185476
# 273                   Dest.LBB             0.185321           0.185321
# 274                   Dest.EYW             0.185222           0.185222
# 275                 Origin.SBN             0.185022           0.185022
# 276                   Dest.EUG             0.183399           0.183399
# 277                 Origin.EYW             0.183302           0.183302
# 278                   Dest.SDF             0.182639           0.182639
# 279                   Dest.ERI             0.181201           0.181201
# 280                   Dest.AMA             0.177660           0.177660
# 281           Dest.missing(NA)             0.000000           0.000000
# 282         Origin.missing(NA)             0.000000           0.000000
# 283  UniqueCarrier.missing(NA)             0.000000           0.000000
#
#      percentage
# 0      0.010675
# 1      0.010294
# 2      0.009981
# 3      0.009797
# 4      0.007281
# 5      0.007195
# 6      0.007013
# 7      0.006789
# 8      0.006761
# 9      0.006514
# 10     0.005964
# 11     0.005856
# 12     0.005780
# 13     0.005728
# 14     0.005641
# 15     0.005552
# 16     0.005543
# 17     0.005543
# 18     0.005482
# 19     0.005470
# 20     0.005470
# 21     0.005451
# 22     0.005439
# 23     0.005424
# 24     0.005391
# 25     0.005380
# 26     0.005364
# 27     0.005306
# 28     0.005245
# 29     0.005231
# ..          ...
# 254    0.002097
# 255    0.002091
# 256    0.002079
# 257    0.002077
# 258    0.002074
# 259    0.002066
# 260    0.002061
# 261    0.002044
# 262    0.002042
# 263    0.002040
# 264    0.002033
# 265    0.002030
# 266    0.002023
# 267    0.002022
# 268    0.002015
# 269    0.002012
# 270    0.002003
# 271    0.002001
# 272    0.001980
# 273    0.001978
# 274    0.001977
# 275    0.001975
# 276    0.001958
# 277    0.001957
# 278    0.001950
# 279    0.001934
# 280    0.001897
# 281    0.000000
# 282    0.000000
# 283    0.000000
#
# [284 rows x 4 columns]

# %%
h2o.shutdown(prompt=False)
