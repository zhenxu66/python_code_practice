# %%
import threading

def printit():
  threading.Timer(10.0, printit).start()
  # %run music_rank.py

printit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# D:\git\python\music_rank.py in <module>()
#      55
#      56 #print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$  Top Five song and Singers   $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$\n")
# ---> 57 get_single_item_data("http://realtime.billboard.com/?chart=trending140", 70, 90)
#      58
#      59
#
# D:\git\python\music_rank.py in get_single_item_data(item_url, number_start, num_end)
#      42         rank_list = toplist[1].find_all('tr')
#      43         for rank in rank_list[number_start:num_end]:
# ---> 44             rank_no.append(rank.find_all('td')[0].text)
#      45             artist.append(rank.find_all('td')[1].text)
#      46             music_text = rank.find_all('td')[2].text
#
# NameError: name 'rank_no' is not defined
# ---------------------------------------------------------------------------
# ...
